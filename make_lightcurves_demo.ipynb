# %%
from MakeLightcurves import *
# Out:
# lk version: 1.0b30
# /Users/charlotte/Dropbox (MIT)/Code/tess_k2_overlap/MakeLightcurves.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   combined = pandas.concat([crossmatch_planets,crossmatch_candidates])

# %%
lc115 = make_lc(hostname='K2-115',mission='tess',verbose=True)
# Out:
# Fetching TPF...
# De-trending...
# Success

# %%
dict115 = {'b':[2458495.156286563,2458515.429379863]}

# %%
plot_lc(lc=lc115,hostname='K2-115',transit_dict=dict115)

# %%
plot_lc(hostname='K2-115',transit_dict=dict115)
