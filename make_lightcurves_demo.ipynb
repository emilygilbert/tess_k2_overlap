# %%
from make_lightcurves import *
# Out:
# lk version: 1.0b30

# %%
tic115,tess115 = make_lc(7020254,'tess')

# %%
dict115 = {'b':[2458495.156286563,2458515.429379863]}

# %%
print(tess115)
# Out:
# TessLightCurve(TICID: 7020254)

# %%
plot_lc(tess115,'K2-115 b',dict115)
