# %%
from make_lightcurves import *
# Out:
# lk version: 1.0b30
# /Users/charlotte/Dropbox (MIT)/Code/tess_k2_overlap/make_lightcurves.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   combined_info = pandas.concat([planet_info,candidate_info])

# %%
print(combined_info)
# Out:
#           DEC       EPIC          RA        TIC  Unnamed: 0 pl_hostname  \
# 0  -18.011170  205904628  336.575788   69747919           0      K2-167
# 1  -17.543994  205916793  338.054185   12822545           1       K2-54
# 2  -14.069886  206026136  342.691712  146799150           2       K2-57
# 3   12.572612  210363145   55.228426  435339847           3       K2-77
# 4   13.559289  210403955   59.037487  242961495           4       K2-80
# 5   13.559289  210403955   59.037487  242961495           5       K2-80
# 6   13.559289  210403955   59.037487  242961495           6       K2-80
# 7   10.080375  211311380  126.616038  366443426           7   HIP 41378
# 8   10.080375  211311380  126.616038  366443426           8   HIP 41378
# 9   10.080375  211311380  126.616038  366443426           9   HIP 41378
# 10  10.080375  211311380  126.616038  366443426          10   HIP 41378
# 11  10.080375  211311380  126.616038  366443426          11   HIP 41378
# ...

# %%
lc115 = make_lc(tic=7020254,mission='tess',verbose=True)
# Out:
# Fetching TPF...
# De-trending...
# Success

# %%
test_colors()

# %%
dict115 = {'b':[2458495.156286563,2458515.429379863]}

# %%
plot_lc(lc=lc115,planet='K2-115 b',transit_dict=dict115)

# %%
plot_lc(planet='K2-115 b',transit_dict=dict115)
